# %% [markdown]
# <!-- # _PANDAS_ -->
# <center><span ><h1><i> PANDAS </i></h1></span></center>
#
# ![PandaLogo.svg](PandaLogo.svg)

# %% [markdown]
# ### Importamos la libreia PANDAS, al igual que lo hemos hecho con numpy y matplotlib.pyplot este tambien tiene un alias convencionalmente usado

# %%
# estos 3 siempre deben de ir juntos

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd # Convención pd
import seaborn as sns

# %% [markdown]
# ## Series
# ### Una serie es una matriz **etiquetada** unidimensional capaz de contener cualquier tipo de dato( enteros, cadenas, flotantes, objetos Python, etc. ). Pero a diferencia de un vector usual de numpy, este cuenta con una columna o eje de indexación.
#
# ### Se invoca a traves del metodo _pd.Series(data, index = indices)_ donde data puede ser difernetes dtipos de elementos:
#    * Diccionarios de Pyhton
#    * Listas de Python
#    * Un Valor escalar
#    * Un arreglo de numpy (ndarray)

# %%
class Tabla:
  def __init__(self) -> None:
    self.__datos = pd.DataFrame(np.zeros((10,50)))
    self.__columnas = self.__datos.columns
    self.__filas = self.__datos.index

  def promedio(self):
     self.__promedio = self.__datos.mean(axis = 0, skipna=True, numeric_only=True)
     return self.__promedio

# %%
d = {"b": 1, "a": 0, "c": 2} # b,a,c= filas, indices
ds1 = pd.Series(d, name = "Valor") #serie= una sola columna
ds1
# si yo quito el d y pongo [1,2,3,4,5,6] va a generar los indices como 0,1,2,3,4,5 y a la columna como es una sola tambien le pone un nombre, en este caso 0

# print("\n")
# print(ds1.index,"\n")
ds2 = pd.Series(np.random.randn(5), index=np.arange(5,15,2))# el primer argumento es son los nombres de las columnas.
# #El segundo argumento es los indices.
# display(ds2)
ds3 = pd.Series("Hola", index=["a", "b", "c", "d", "e"],name ="entrada")
ds3["a"]="mundo"
# ds1["f"]="Mundo"
# display(ds1)
display(ds3)
# ds4 = pd.Series([5,3,6], index=[1,2,3])
# ds4
# Out:
# a    mundo
# b     Hola
# c     Hola
# d     Hola
# e     Hola
# Name: entrada, dtype: object

# %% [markdown]
# ### DATAFRAMES
#
# ### Es una estructura de datos etiquetada, bidimensional, con columnas de tipos potencialmente diferentes. Puedes pensarlo como una hoja de cálculo, o tabla SQL, o un diccionario de  objetos tipo serie. Generalmente es el objeto utilizado de pandas.
#
# ### Al igual que Series, DataFrame acepta muchos tipos diferentes de entrada:
# * Dict de ndarrays 1D, listas, dicts o Series
# * 2-D numpy.ndarray
# * Una Series
# * Matriz estructurada (registro txt,cvs, xls, etc..)
# * Otro DataFrame

# %% [markdown]
# ## Desde  diccionarios de series , listas y diccionarios

# %%
d = {"one": pd.Series([1.0, 2.0, 3.0,5,4,34], index=["a", "b", "c","d","e","f"]),
    "two": pd.Series([1.0, 3.0, 4.0,7], index=["a" , "c", "d","e"]),
    "three": pd.Series([1.0, 3.0, 4.0,7], index=["a" , "c", "d","e"])}
df = pd.DataFrame(d)
# df = pd.DataFrame(d)
df["four"]=pd.Series([1.0, 3.0, 4.0,7], index=["a" , "c", "d","e"])
df
# Out:
#     one  two  three  four
# a   1.0  1.0    1.0   1.0
# b   2.0  NaN    NaN   NaN
# c   3.0  3.0    3.0   3.0
# d   5.0  4.0    4.0   4.0
# e   4.0  7.0    7.0   7.0
# f  34.0  NaN    NaN   NaN

# %%
w = df.drop(['four'], axis=1, inplace=False) # Borra Columnas
print(w)
# Out:
#     one  two  three
# a   1.0  1.0    1.0
# b   2.0  NaN    NaN
# c   3.0  3.0    3.0
# d   5.0  4.0    4.0
# e   4.0  7.0    7.0
# f  34.0  NaN    NaN

# %%
# Por filas solamente e igual que python
# display(df['a':'c'])
# display(df[["one","four","two"]])  #Seleccionar las columnas "one" y "Cuatro" del DataFrame df.
#SOLO SE PUEDE HACER POR FILAS O COLUMNAS, PERO NO POR AMBAS AL TIEMPO
# iloc: Se usa para seleccionar filas y columnas por posición (basado en índices enteros, como en NumPy).
# loc: Se usa para seleccionar filas y columnas por etiquetas (nombres de columnas o índices de filas).

# display(df.iloc[2:6,0:3]) # Selecciona la fila en la posición 2 (la fila en el índice c) y 0:3: Selecciona las columnas en las posiciones 0, 1 y 2 (las primeras tres columnas)
display(df.loc['b':'e', "two":"four"])  #b':'e': Selecciona las filas desde la etiqueta 'b' hasta 'e' (incluyendo ambos). ["one", "Cuatro"]: Selecciona solo las columnas "one" y "Cuatro".
# h=pd.DataFrame(df.loc['b':'e', 'one']) #Crea un nuevo DataFrame h que contiene únicamente la columna "one" y las filas desde 'b' hasta 'e'.
# display(h)
# Out:
#    two  three  four
# b  NaN    NaN   NaN
# c  3.0    3.0   3.0
# d  4.0    4.0   4.0
# e  7.0    7.0   7.0

# %% [markdown]
# ## Otra forma de hacerlo , indicando columnas

# %%
# pd.DataFrame(d, index=["a", "b", "c","d","x","f"])
pd.DataFrame(d, index=["x", "y", "z","w","q","h"])
# pd.DataFrame(d)
# pd.DataFrame(d, index=["a", "b", "c"], columns=["three", "four"])
# Out:
#    one  two  three
# x  NaN  NaN    NaN
# y  NaN  NaN    NaN
# z  NaN  NaN    NaN
# w  NaN  NaN    NaN
# q  NaN  NaN    NaN
# h  NaN  NaN    NaN

# %% [markdown]
# ## Llamando los índices y columnas

# %%
print(df.index)
print(df.columns)
print(len(df.columns))
print(df.shape)
print(df.size)
print(df.ndim)
# Out:
# Index(['a', 'b', 'c', 'd', 'e', 'f'], dtype='object')
# Index(['one', 'two', 'three', 'four'], dtype='object')
# 4
# (6, 4)
# 24
# 2

# %% [markdown]
# ## De diccionarios de ndarrays / list

# %%
d = {"DxHL":np.linspace(1,2,4), "two": [4.0, 3.0, 2.0, 1.0] }
# display(pd.DataFrame(d))
#linspace(#inicio,#numero final,cantidad de datos)
display(pd.DataFrame(d,index=["Pepito Perez", "Pepito Perez ", "Entrada 3", "Entrada 3"]))
# pd.DataFrame(d, index=["Pepito Perez", "Pepito Perez ", "Entrada 3", "Entrada 3"])
# Out:
#                    DxHL  two
# Pepito Perez   1.000000  4.0
# Pepito Perez   1.333333  3.0
# Entrada 3      1.666667  2.0
# Entrada 3      2.000000  1.0

# %% [markdown]
# ## Desde una matriz de ndarray mas estructurada

# %%
data = np.zeros((4,), dtype=[("A", "i4"), ("B", "f4"), ("C", "U10")])
# data
data[:2] = [(1, 2.0, "Hello"), (2, 3.0, "World")]
print(data)
pd.DataFrame(data)
# # pd.DataFrame(data, index=["first", "second","third","fourth"],columns=["A", "B", "C"])
# pd.DataFrame(data, index=["first", "second","third","fourth"])
# Out:
# [(1, 2., 'Hello') (2, 3., 'World') (0, 0., '') (0, 0., '')]
#    A    B      C
# 0  1  2.0  Hello
# 1  2  3.0  World
# 2  0  0.0
# 3  0  0.0

# %% [markdown]
# ## Los nombres usados son los siguientes
# * 'i1': Entero con signo de 8 bits
# * 'i2': Entero con signo de 16 bits
# * 'i4': Entero con signo de 32 bits
# * 'i8': Entero con signo de 64 bits
# * 'u1': Entero sin signo de 8 bits
# * 'u2': Entero sin signo de 16 bits
# * 'u4': Entero sin signo de 32 bits
# * 'u8': Entero sin signo de 64 bits
# * 'f2': Punto flotante de 16 bits
# * 'f4': Punto flotante de 32 bits
# * 'f8': Punto flotante de 64 bits
# * bool_: Tipo booleano.
# * object_: Tipo de objeto de Python, que permite almacenar cualquier objeto de Python en un array NumPy.
# * 'byte_str' 'S' 'a': Cadenas de bytes (ASCII)
# * 'unicode_str' 'U': Unicode (UTF-32)
# * 'obj_str' 'O': String de cualquier longitud
# * datetime64: Tipo de datos que representa fechas y horas en unidades de tiempo de 64 bits.
# * timedelta64: Tipo de datos que representa una duración o diferencia de tiempo entre dos datetime64.
# * void: Tipo de datos estructurados sin formato que pueden contener varios tipos de datos.

# %%
dict_data = {'edad' :[ 10, 9, 13, 14, 12, 11, 12],
    'cm' :[115, 110, 130, 155, 125, 120, 125],
    'pais' :[ 'co', 'mx', 'co', 'mx', 'mx', 'ch', 'ch'],
    'genero' :[ 'M', 'F', 'F', 'M', 'M', 'M', 'F'],
    'Q1' :[5, 10, 8, np.nan, 7, 8, 3],
    'Q2' :[7, 9, 9, 8, 8, 8, 9.] }
df = pd.DataFrame(dict_data)
df
# Out:
#    edad   cm pais genero    Q1   Q2
# 0    10  115   co      M   5.0  7.0
# 1     9  110   mx      F  10.0  9.0
# 2    13  130   co      F   8.0  9.0
# 3    14  155   mx      M   NaN  8.0
# 4    12  125   mx      M   7.0  8.0
# 5    11  120   ch      M   8.0  8.0
# 6    12  125   ch      F   3.0  9.0

# %% [markdown]
# ## Existen muchos tipos de formatos a los cuales podemos convertir un DataFrame tales como:
# * ### Excel
# * ### CSV
# * ### HDF
# * ### Json
# * ### Parquet
# * ### Pickle
#
# ### A continuación algunos ejemplos. Partiremos de un DataFrame y los convertiremos a los diferentes formatos, despues leeremos desde dichos archivos(implicitamente es una conversión a tipo de dato DataFrame).

# %%
df.to_excel("test.xlsx",index=False)
df.to_csv("test.csv",index=True)
df.to_hdf("test.hdf",key='data',format='table')
df.to_json("test.json")
df.to_parquet("test.parquet")
df.to_pickle("test.pkl")

# %%
# Al leerlos ya son objetos tipo DataFrame
fExcel= pd.read_excel("test.xlsx")
fCSV= pd.read_csv("test.csv")
fHDF= pd.read_hdf("test.hdf")
fJson= pd.read_json("test.json")
fparquet= pd.read_parquet("test.parquet")
fPickle= pd.read_pickle("test.pkl")

# %%
print(type(fCSV))
print(type(fExcel))
print(type(fHDF))
print(type(fJson))
print(type(fparquet))
print(type(fPickle))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>

# %%
fCSV
# Out:
#    Unnamed: 0  edad   cm pais genero    Q1   Q2
# 0           0    10  115   co      M   5.0  7.0
# 1           1     9  110   mx      F  10.0  9.0
# 2           2    13  130   co      F   8.0  9.0
# 3           3    14  155   mx      M   NaN  8.0
# 4           4    12  125   mx      M   7.0  8.0
# 5           5    11  120   ch      M   8.0  8.0
# 6           6    12  125   ch      F   3.0  9.0

# %%
# type(fExcel)
w = fCSV.drop(['Unnamed: 0'],axis=1) # Borra Columnas
w = w.drop([2,5]) # Borra Filas
# q = fCSV.dropna()
print(w)
# Out:
#    edad   cm pais genero    Q1   Q2
# 0    10  115   co      M   5.0  7.0
# 1     9  110   mx      F  10.0  9.0
# 3    14  155   mx      M   NaN  8.0
# 4    12  125   mx      M   7.0  8.0
# 6    12  125   ch      F   3.0  9.0

# %%
fCSV
# Out:
#    edad   cm pais genero    Q1   Q2
# 0    10  115   co      M   5.0  7.0
# 1     9  110   mx      F  10.0  9.0
# 2    13  130   co      F   8.0  9.0
# 3    14  155   mx      M   NaN  8.0
# 4    12  125   mx      M   7.0  8.0
# 5    11  120   ch      M   8.0  8.0
# 6    12  125   ch      F   3.0  9.0

# %% [markdown]
# ## Visualizo el daframe leido en cada uno de los formatos

# %%
# print(type(fExcel))
# fExcel
# fCSV
fHDF
# fJson
# fparquet
# fPickle
# Out:
#    edad   cm pais genero    Q1   Q2
# 0    10  115   co      M   5.0  7.0
# 1     9  110   mx      F  10.0  9.0
# 2    13  130   co      F   8.0  9.0
# 3    14  155   mx      M   NaN  8.0
# 4    12  125   mx      M   7.0  8.0
# 5    11  120   ch      M   8.0  8.0
# 6    12  125   ch      F   3.0  9.0

# %% [markdown]
# ## Generar columnas nuevas

# %%
fExcel.loc[:,'pais':'Q2']
# Out:
#   pais genero    Q1  Q2
# 0   co      M   5.0   7
# 1   mx      F  10.0   9
# 2   co      F   8.0   9
# 3   mx      M   NaN   8
# 4   mx      M   7.0   8
# 5   ch      M   8.0   8
# 6   ch      F   3.0   9

# %%
fExcel["Promedio2"] = fExcel[['Q1','Q2']].mean(axis=1,skipna=True, numeric_only=True)
# fExcel['Metros']= fExcel['cm']/100
# fExcel.drop(['Promedio','genero'], axis=1, inplace=True)
fExcel
# Out:
#    edad   cm pais genero    Q1  Q2  Promedio  Promedio2
# 0    10  115   co      M   5.0   7  8.285714        6.0
# 1     9  110   mx      F  10.0   9  8.285714        9.5
# 2    13  130   co      F   8.0   9  8.285714        8.5
# 3    14  155   mx      M   NaN   8  8.285714        8.0
# 4    12  125   mx      M   7.0   8  8.285714        7.5
# 5    11  120   ch      M   8.0   8  8.285714        8.0
# 6    12  125   ch      F   3.0   9  8.285714        6.0

# %%
# Usando la otra variable q se habia creado

fExcel["Sumatoria"] = fExcel[['Q1','Q2']].sum(axis = 1,skipna=False)
fExcel['Metro']= 100
fExcel
# Out:
#    edad   cm pais genero    Q1  Q2  Promedio  Promedio2  Sumatoria  Metro
# 0    10  115   co      M   5.0   7  8.285714        6.0       12.0    100
# 1     9  110   mx      F  10.0   9  8.285714        9.5       19.0    100
# 2    13  130   co      F   8.0   9  8.285714        8.5       17.0    100
# 3    14  155   mx      M   NaN   8  8.285714        8.0        NaN    100
# 4    12  125   mx      M   7.0   8  8.285714        7.5       15.0    100
# 5    11  120   ch      M   8.0   8  8.285714        8.0       16.0    100
# 6    12  125   ch      F   3.0   9  8.285714        6.0       12.0    100

# %%
fExcel.drop(['Metro'], axis=1, inplace=True)
fExcel
# Out:
#    edad   cm pais genero    Q1  Q2  Promedio  Promedio2  Sumatoria
# 0    10  115   co      M   5.0   7  8.285714        6.0       12.0
# 1     9  110   mx      F  10.0   9  8.285714        9.5       19.0
# 2    13  130   co      F   8.0   9  8.285714        8.5       17.0
# 3    14  155   mx      M   NaN   8  8.285714        8.0        NaN
# 4    12  125   mx      M   7.0   8  8.285714        7.5       15.0
# 5    11  120   ch      M   8.0   8  8.285714        8.0       16.0
# 6    12  125   ch      F   3.0   9  8.285714        6.0       12.0

# %%
fCSV

# %%
fCSV['genero'] = fCSV['genero'].replace({"M":0,"F":1})
fCSV
# Out:
# /tmp/ipykernel_1105/3027978500.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   fCSV['genero'] = fCSV['genero'].replace({"M":0,"F":1})
#    edad   cm pais  genero    Q1   Q2
# 0    10  115   co       0   5.0  7.0
# 1     9  110   mx       1  10.0  9.0
# 4    12  125   mx       0   7.0  8.0
# 6    12  125   ch       1   3.0  9.0

# %%
print(np.sum(fHDF['genero']=="F"))
# Out:
# 3

# %%
fHDF['genero']=="F"
# Out:
# 0    False
# 1     True
# 2     True
# 3    False
# 4    False
# 5    False
# 6     True
# Name: genero, dtype: bool

# %%
fHDF.loc[fHDF['genero']=="F",'genero']=1
fHDF.loc[fHDF['genero']=="M",'genero']=0
fHDF
# fHDF.loc[0:4,['pais','edad','Q1']]
# Out:
#    edad   cm pais genero    Q1   Q2
# 0    10  115   co      0   5.0  7.0
# 1     9  110   mx      1  10.0  9.0
# 2    13  130   co      1   8.0  9.0
# 3    14  155   mx      0   NaN  8.0
# 4    12  125   mx      0   7.0  8.0
# 5    11  120   ch      0   8.0  8.0
# 6    12  125   ch      1   3.0  9.0

# %%
fCSV.loc[fCSV['cm']>117,'Q2']="Aprobados"
fCSV
# Out:
# /tmp/ipykernel_4355/3074746085.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Aprobados' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   fCSV.loc[fCSV['cm']>117,'Q2']="Aprobados"
#    Unnamed: 0  edad   cm pais genero    Q1         Q2
# 0           0    10  115   co      M   5.0        7.0
# 1           1     9  110   mx      F  10.0        9.0
# 2           2    13  130   co      F   8.0  Aprobados
# 3           3    14  155   mx      M   NaN  Aprobados
# 4           4    12  125   mx      M   7.0  Aprobados
# 5           5    11  120   ch      M   8.0  Aprobados
# 6           6    12  125   ch      F   3.0  Aprobados

# %%
fHDF['pais'][fHDF['genero']==1]="Aprobó"
fHDF
# Out:
# /tmp/ipykernel_4355/3758048584.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   fHDF['pais'][fHDF['genero']==1]="Aprobó"
# /tmp/ipykernel_4355/3758048584.py:1: SettingWithCopyWarning:
# ...

# %%
print(fExcel.shape)
print(fCSV.shape)
print(fHDF.shape)
print(fJson.shape)
print(fparquet.shape)
print(fPickle.shape)

# %% [markdown]
# # **_Práctica con archivos de KAGGLE_**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# https://www.kaggle.com/datasets/shayanfazeli/heartbeat?resource=download de este link salieron estos datos
# son de un estudio de categorización de arritmias del hospital  BethIsarael en Boston en conjunto con MIT
# https://www.kaggle.com/datasets/imdevskp/corona-virus-report?select=covid_19_clean_complete.csv estos datos
# son de confirmaciones de casos de covid en diferentes regiones del mundo

# df_ecg = pd.read_csv("mitbih_test.csv",header = None)
df_covid = pd.read_csv("/content/drive/My Drive/Colab Notebooks/db/covid.csv")
# df_covid.head(6)
df_covid.tail(10)
# df_covid.iloc[[1,36,200],[4,5,8]]
# df2 = df_covid.loc[[1,36,200],["Date",'Confirmed',"Active", "Deaths"]].copy()
# df2.drop("Date", axis=1, inplace=True)
# df_covid.loc[df_covid['WHO Region']=="Europe",:]
# Out:
#                     Province/State         Country/Region        Lat  \
# 49058                          NaN                 Malawi -13.254300
# 49059  Falkland Islands (Malvinas)         United Kingdom -51.796300
# 49060    Saint Pierre and Miquelon                 France  46.885200
# 49061                          NaN            South Sudan   6.877000
# 49062                          NaN         Western Sahara  24.215500
# 49063                          NaN  Sao Tome and Principe   0.186400
# 49064                          NaN                  Yemen  15.552727
# 49065                          NaN                Comoros -11.645500
# 49066                          NaN             Tajikistan  38.861000
# 49067                          NaN                Lesotho -29.610000
#
#             Long        Date  Confirmed  Deaths  Recovered  Active  \
# 49058  34.301500  2020-07-27       3664      99       1645    1920
# 49059 -59.523600  2020-07-27         13       0         13       0
# ...

# %%
(df_covid['Country/Region']=="France").sum()
# Out:
# np.int64(2068)

# %%
# df_covid.groupby(['WHO Region']).median(numeric_only=True)
df_covid.groupby(['WHO Region']).mean(numeric_only=True).plot(kind= 'bar')
# df_covid.groupby(['Country/Region']).sum(numeric_only=True).plot(kind='bar')
# Out:
# <Axes: xlabel='WHO Region'>

# %% [markdown]
# ## Atributos

# %%
print("Dimension: ", df_covid.ndim)
print("Tamaño: ", df_covid.size)
print("Forma: ",df_covid.shape)
print("Columnas: ", df_covid.columns,"\n")
print(5*">","Informacion general:".upper(),5*">","\n")
print(df_covid.info())
# print(f"{5*'<'}{'Descripcion estadistica'.upper()}{5*'>'}:\n ",df_covid.describe()) # Cualidades estadisticas de la variables numéricas
print("Descripcion demas varibles:\n ",df_covid.describe(include='all')) # Incluye cualidades de la variables no numericas
# Out:
# Dimension:  2
# Tamaño:  490680
# Forma:  (49068, 10)
# Columnas:  Index(['Province/State', 'Country/Region', 'Lat', 'Long', 'Date', 'Confirmed',
#        'Deaths', 'Recovered', 'Active', 'WHO Region'],
#       dtype='object')
#
# >>>>> INFORMACION GENERAL: >>>>>
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49068 entries, 0 to 49067
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Province/State  14664 non-null  object
#  1   Country/Region  49068 non-null  object
#  2   Lat             49068 non-null  float64
#  3   Long            49068 non-null  float64
#  4   Date            49068 non-null  object
#  5   Confirmed       49068 non-null  int64
#  6   Deaths          49068 non-null  int64
#  7   Recovered       49068 non-null  int64
#  8   Active          49068 non-null  int64
#  9   WHO Region      49068 non-null  object
# dtypes: float64(2), int64(4), object(4)
# memory usage: 3.7+ MB
# ...

# %%
pd.options.display.float_format = '{:.2f}'.format # Modifica el formato de visualizacion de la variables

# %%
print(df_covid.dtypes)
print("\nYa convertidas\n\n",df_covid.convert_dtypes().dtypes)
# Out:
# Province/State     object
# Country/Region     object
# Lat               float64
# Long              float64
# Date               object
# Confirmed           int64
# Deaths              int64
# Recovered           int64
# Active              int64
# WHO Region         object
# dtype: object
#
# Ya convertidas
#
#  Province/State    string[python]
# Country/Region    string[python]
# Lat                      Float64
# Long                     Float64
# Date              string[python]
# Confirmed                  Int64
# Deaths                     Int64
# Recovered                  Int64
# Active                     Int64
# WHO Region        string[python]
# dtype: object

# %% [markdown]
# ### Similar a un diccionario de python pasamos por "clave" el nombre de la columna y este traera todos los datos de la misma, adicionalmente la longitud y el dtype de la columna

# %%
df_covid[["Lat","Long"]]
# Out:
#          Lat  Long
# 0      33.94 67.71
# 1      41.15 20.17
# 2      28.03  1.66
# 3      42.51  1.52
# 4     -11.20 17.87
# ...      ...   ...
# 49063   0.19  6.61
# 49064  15.55 48.52
# 49065 -11.65 43.33
# 49066  38.86 71.28
# 49067 -29.61 28.23
#
# [49068 rows x 2 columns]

# %% [markdown]
# ### Podemos indexar varias columnas al mismo tiempo, algo que con los arreglos de numpy no es tan practico.

# %%
# df_covid[["Province/State","Lat", "Active", "Lat"]]
# df_covid[["Province/State","Lat", "Active", "Lat"]].head(10) # Diez primeros
# df_covid[["Province/State","Lat", "Active", "Lat"]].tail(10) # Diez últimos
df_covid[["Province/State","Lat", "Active", "Lat"]].sample(10) # Muestra de 10 aleatorios
# Out:
#       Province/State    Lat  Active    Lat
# 38531          Aruba  12.52       0  12.52
# 14206      St Martin  18.07       2  18.07
# 22339            NaN  21.01       4  21.01
# 23565        Sichuan  30.62       4  30.62
# 27504            NaN  15.18       9  15.18
# 23226            NaN -11.65       0 -11.65
# 28563            NaN  46.23   93624  46.23
# 8402       Chongqing  30.06     234  30.06
# 41936            NaN   8.54   17174   8.54
# 5066      Guadeloupe  16.27       0  16.27

# %% [markdown]
# -preguntar por Sample
# - y por función seno como arrays

# %%
df_covid.loc[400:410:2,["Active","Province/State","Lat"]]
# Out:
#      Active Province/State   Lat
# 400       0            NaN 48.02
# 402       1            NaN 35.91
# 404       0            NaN 41.20
# 406       0            NaN 33.85
# 408       0            NaN 47.14
# 410       0            NaN 49.82

# %%
print("\t******\n")
display(df_covid.iloc[2,1],"\n\n\t******\n\n")
display(df_covid.iloc[[2,4,5],[1,3]])
display("\n\n\t******\n\n")
df_covid.iloc[[2,4,5],[1,3]]
# Out:
# 	******
# 'Algeria'
# '\n\n\t******\n\n'
#         Country/Region   Long
# 2              Algeria   1.66
# 4               Angola  17.87
# 5  Antigua and Barbuda -61.80
# '\n\n\t******\n\n'
#         Country/Region   Long
# 2              Algeria   1.66
# 4               Angola  17.87
# 5  Antigua and Barbuda -61.80

# %%
# print(df_covid['Province/State'].isna().sum())
print(df_covid['Province/State'].isnull().sum())
df_covid.head(10)
# Out:
# 34404
#                  Province/State       Country/Region    Lat   Long  \
# 0                           NaN          Afghanistan  33.94  67.71
# 1                           NaN              Albania  41.15  20.17
# 2                           NaN              Algeria  28.03   1.66
# 3                           NaN              Andorra  42.51   1.52
# 4                           NaN               Angola -11.20  17.87
# 5                           NaN  Antigua and Barbuda  17.06 -61.80
# 6                           NaN            Argentina -38.42 -63.62
# 7                           NaN              Armenia  40.07  45.04
# 8  Australian Capital Territory            Australia -35.47 149.01
# 9               New South Wales            Australia -33.87 151.21
#
#          Date  Confirmed  Deaths  Recovered  Active             WHO Region
# 0  2020-01-22          0       0          0       0  Eastern Mediterranean
# ...

# %%
df_covid.loc[df_covid["Active"] >= 20000,:]
# Out:
#       Province/State  Country/Region        Lat        Long        Date  \
# 3976           Hubei           China  30.975600  112.270700  2020-02-06
# 4237           Hubei           China  30.975600  112.270700  2020-02-07
# 4498           Hubei           China  30.975600  112.270700  2020-02-08
# 4759           Hubei           China  30.975600  112.270700  2020-02-09
# 5020           Hubei           China  30.975600  112.270700  2020-02-10
# ...              ...             ...        ...         ...         ...
# 49006            NaN           Spain  40.463667   -3.749220  2020-07-27
# 49010            NaN          Sweden  60.128161   18.643501  2020-07-27
# 49020            NaN         Ukraine  48.379400   31.165600  2020-07-27
# 49028            NaN  United Kingdom  55.378100   -3.436000  2020-07-27
# 49030            NaN              US  40.000000 -100.000000  2020-07-27
#
#        Confirmed  Deaths  Recovered   Active       WHO Region
# ...

# %%
]df_covid[df_covid["Active"] >= 20000.loc[:,['Lat','Date']]
# Out:
#              Lat        Date
# 3976   30.975600  2020-02-06
# 4237   30.975600  2020-02-07
# 4498   30.975600  2020-02-08
# 4759   30.975600  2020-02-09
# 5020   30.975600  2020-02-10
# ...          ...         ...
# 49006  40.463667  2020-07-27
# 49010  60.128161  2020-07-27
# 49020  48.379400  2020-07-27
# 49028  55.378100  2020-07-27
# 49030  40.000000  2020-07-27
#
# [2821 rows x 2 columns]

# %%
def my_function(n):
    return lambda x: x * n

double = my_function(2)
triple = my_function(3)

print(double(8))
print(triple(9))
# Out:
# 16
# 27

# %% [markdown]
# # Apply y Applymap o map(versiones actuales)

# %%
df_covid['Confirmed']
# Out:
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
#          ...
# 49063     865
# 49064    1691
# 49065     354
# 49066    7235
# 49067     505
# Name: Confirmed, Length: 49068, dtype: int64

# %%
# df_covid['Confirmed'].apply(my_function(3))
# df_covid['Confirmed'].apply(lambda x: x * 3)

display(df_covid[["Lat","Active"]])
df_covid[["Lat","Active"]].apply(lambda x:x.mean(),axis=0)
# Out:
#              Lat  Active
# 0      33.939110       0
# 1      41.153300       0
# 2      28.033900       0
# 3      42.506300       0
# 4     -11.202700       0
# ...          ...     ...
# 49063   0.186400     117
# 49064  15.552727     375
# 49065 -11.645500      19
# 49066  38.861000    1147
# 49067 -29.610000     365
#
# [49068 rows x 2 columns]
# Lat         21.433730
# Active    8085.011617
# dtype: float64

# %%
df_covid[['Confirmed', 'Deaths', 'Recovered', 'Active']].mean().plot(kind='bar')
# Out:
# <Axes: >

# %%
meanD = df_covid[['Confirmed', 'Deaths', 'Recovered', 'Active']].mean()
# meanD.index
plt.bar(meanD.index, meanD.values)
# Out:
# <BarContainer object of 4 artists>

# %%
# df_covid.hist(['Confirmed','Deaths','Recovered', 'Active'],)
df_covid['Confirmed'].plot()
# Out:
# <Axes: >

# %%
import seaborn as sns

# %%
sns.load_dataset("flights")
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
flights
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
import seaborn as sns


flights=sns.load_dataset("flights")
sns.lineplot(data=flights, x='year', y='passengers', hue='month')
plt.title('Número de pasajeros por año y mes')
plt.show()
iris=sns.load_dataset("iris")
sns.scatterplot(data=iris, x='sepal_length', y='sepal_width', hue='species')
plt.title('Relación entre longitud y ancho del sépalo por especie')
plt.show()
tips = sns.load_dataset('tips')
sns.barplot(data=tips, x='day', y='total_bill', hue='sex')
plt.title('Total de la cuenta por día y sexo')
plt.show()

# %%
fmri
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Cargar el dataset fmri
print(sns.get_dataset_names()) # Muestra todos los datasets con los que cuenta la libreria seaborn
fmri = sns.load_dataset("fmri")

# Mostrar la activación cerebral a lo largo del tiempo
plt.figure(figsize=(10, 6))
sns.lineplot(data=fmri, x="timepoint", y="signal", hue="event", style="region", errorbar=("ci", 95))
plt.title("Activación cerebral a lo largo del tiempo (dataset fmri)")
plt.xlabel("Tiempo")
plt.ylabel("Cambio de señal BOLD")
plt.show()

# Otro gráfico que muestra la activación promedio por región y evento
plt.figure(figsize=(10, 6))
sns.barplot(data=fmri, x="region", y="signal", hue="event", errorbar=("ci", 95))
plt.title("Activación cerebral promedio por región y evento")
plt.xlabel("Región")
plt.ylabel("Cambio de señal BOLD promedio")
plt.show()
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']
