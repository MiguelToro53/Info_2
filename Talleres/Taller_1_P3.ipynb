# %%
import os.path as path
if path.exists('MRI.png'):   
    print ('El archivo ya existe')
else:
    # !wget -nc https://www.dropbox.com/s/tv9r24hbwlxojee/MRI.png?dl=1
    # !mv MRI.png?dl=1 MRI.png
# Out:
# 7[Files: 0  Bytes: 0  [0 B/s] Re]87[https://www.dropbox.com/s/tv9r]87MRI.png?dl=1           0% [>                             ]       0          B/s87HTTP response 302  [https://www.dropbox.com/s/tv9r24hbwlxojee/MRI.png?dl=1]
# 87MRI.png?dl=1           0% [>                             ]       0          B/s87Enqueue https://www.dropbox.com/scl/fi/pv3spr6yjjqi7kwkpxgz3/MRI.png?rlkey=87l0afwe5764z2rldpgo840y3&dl=1
# 87[https://www.dropbox.com/scl/fi]87[Files: 0  Bytes: 124  [179 B/s]87[Files: 0  Bytes: 124  [124 B/s]87MRI.png?dl=1           0% [>                             ]       0          B/s87HTTP response 302  [https://www.dropbox.com/scl/fi/pv3spr6yjjqi7kwkpxgz3/MRI.png?rlkey=87l0afwe5764z2rldpgo840y3&dl=1]
# 87MRI.png?dl=1           0% [>                             ]       0          B/s87Enqueue https://uc0a4879097a35b408830d7968df.dl.dropboxusercontent.com/cd/0/inline/DA3wQOBOGiQXNumbwVftgj7U3tK5XK5jI5xTJKuLWgGWYJd9UpV8A7sD8qHeZUuUe6ahkPz6yVEwh5T06N1dk9Qp41nunb6CHZqiqY3kagzSQD08GAKN4UHHv8CD1ZtutNGZVBiscmt1vkyyVJH6Eth7/file?dl=1#
# 87[Files: 0  Bytes: 141  [123 B/s]87[Files: 0  Bytes: 141  [70 B/s]]87[https://uc0a4879097a35b408830d]87[Files: 0  Bytes: 141  [47 B/s]]87Saving 'MRI.png?dl=1'
# 87MRI.png?dl=1         100% [=============================>]  102.78K    --.-KB/s87HTTP response 200  [https://uc0a4879097a35b408830d7968df.dl.dropboxusercontent.com/cd/0/inline/DA3wQOBOGiQXNumbwVftgj7U3tK5XK5jI5xTJKuLWgGWYJd9UpV8A7sD8qHeZUuUe6ahkPz6yVEwh5T06N1dk9Qp41nunb6CHZqiqY3kagzSQD08GAKN4UHHv8CD1ZtutNGZVBiscmt1vkyyVJH6Eth7/file?dl=1#]
# 87MRI.png?dl=1         100% [=============================>]  102.78K    --.-KB/s87[Files: 1  Bytes: 102.92K [30.1]8

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### 1) Lea la imagen 'MRI.png' descargada anteriormente.

# %%
img = cv2.imread('MRI.png')

# %% [markdown]
# ### 2) Imprima las filas, columnas y canales de la imagen.
# Sugerencia: Use ```np.shape()```

# %%
np.shape(img)
# Out:
# (421, 752, 3)

# %% [markdown]
# ### 3) Realice el cambio de color de BRG a escala de grises.
# Lo puede realizar con la función ```cv2.cvtColor()```
# e indicando el cambio del espacio de color como ```cv2.COLOR_BGR2GRAY```

# %%
img_g = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %% [markdown]
# ### 4) Imprima nuevamente las filas, columnas y canales de la imagen.

# %%
np.shape(img_g)
# Out:
# (421, 752)

# %% [markdown]
# ### 5) Grafique la imagen con matplotlib
# Nota: para evitar el falso color por defecto de matplotlib y el ajuste automático de escalas de grises utilice los siguiente argumentos:
#
# ```plt.imshow(ima, cmap='gray', vmin=0, vmax=255)```
#
# donde cmap='gray' indica el mapa de color en escala de grises, vmin el valor mínimo de nivel de gris y vmax el valor máximo.

# %%
plt.imshow(img_g, cmap='gray', vmin=0, vmax=255)
plt.axis('off')
plt.show()

# %% [markdown]
# ### 6) Obtenga el histograma de la imagen y grafíquelo
# Nota: Como la imagen en escala de grises es de un solo canal solo se debe realizar para el canal 0

# %%
hist = cv2.calcHist([img_g], [0], None, [256], [0,256])

plt.plot(hist)
plt.ylabel('cantidad de pixeles')
plt.xlabel('intensidad de gris')
plt.title('Histograma de la imagen')
plt.show()

# %% [markdown]
# ### 7) Realice la ecualización de la imagen mediante la ecualización del histograma

# %%
img_g_eq = cv2.equalizeHist(img_g)

# %% [markdown]
# ### 8) Grafique la imagen ecualizada con las mismas consideraciones del punto 5.

# %%
plt.imshow(img_g_eq, cmap='gray', vmin=0, vmax=255)
plt.axis('off')
plt.show()

# %% [markdown]
# ### 9) Obtenga el histograma de la imagen ecualizada y grafíquelo

# %%
hist_eq = cv2.calcHist([img_g_eq], [0], None, [256], [0,256])

plt.plot(hist_eq)
plt.ylabel('cantidad de pixeles')
plt.xlabel('intensidad de gris')
plt.title('Histograma de la imagen')
plt.show()

# %% [markdown]
# ### 10) Guarde el resultado obtenido como una imagen con extensión .png

# %%
cv2.imwrite('MRI_eq.png', img_g_eq)
if cv2.imwrite('MRI_eq.png', img_g_eq):
    print('La imagen se guardó correctamente')
else:   
    print('Error al guardar la imagen')
# Out:
# La imagen se guardó correctamente

# %% [markdown]
# ### 11) Grafique el resultado en un espacio de color diferente, es decir especificando otro mapa de colores.
# sugerencias: 'viridis', 'plasma', 'inferno', 'magma'
#
# también pueden ver:
#
# https://matplotlib.org/3.1.0/tutorials/colors/colormaps.html

# %% [markdown]
# ### 12) realice el punto 11 pero en otro espacio de color.
